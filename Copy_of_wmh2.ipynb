# %% [markdown]
# <a href="https://colab.research.google.com/github/brostudio000/tugas-akhir/blob/main/Copy_of_wmh2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DataGenerator

# %%
import os
import nibabel as nib
import numpy as np

data_path = "/content/drive/MyDrive/Colab_Notebooks/WMH_Dataset/training/Utrecht/"
seg_samples = [os.path.join(data_path, sample, "wmh_modified.nii.gz") for sample in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, sample))]

saved_values = []
max_nb_values = 0
for sample in seg_samples:
    seg_img = nib.load(sample).get_fdata()
    unique_values = np.unique(seg_img)
    nb_unique_values = len(unique_values)

    if nb_unique_values > max_nb_values:
        max_nb_values = nb_unique_values
        saved_values = unique_values

print(f"Maximum number of values in all segmentation images: {max_nb_values}")
print(f"Values: {saved_values}")
# Out:
# Maximum number of values in all segmentation images: 2
# Values: [0. 1.]

# %%
#import os
#import nibabel as nib
#import numpy as np

data_path = "/content/drive/MyDrive/Colab_Notebooks/WMH_Dataset/training/Utrecht/"
seg_samples = [os.path.join(data_path, sample, "wmh.nii.gz") for sample in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, sample))]

for sample in seg_samples:
    seg_img = nib.load(sample)
    seg_data = seg_img.get_fdata()

    # Remove class 2 (assuming it's represented by the value 2)
    seg_data[seg_data == 2] = 0

    # Save the modified segmentation data
    modified_seg_img = nib.Nifti1Image(seg_data, seg_img.affine)
    nib.save(modified_seg_img, sample.replace("wmh.nii.gz", "wmh_modified.nii.gz"))

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import cv2
import nibabel as nib
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

VOLUME_START_AT = 7
VOLUME_SLICES = 30
IMG_SIZE = 256
N_CHANNELS = 2

data_path = "/content/drive/MyDrive/Colab_Notebooks/WMH_Dataset/training/Utrecht"

# List all patients
patients = os.listdir(data_path)

# Split the dataset into train and validation sets
patients_train, patients_val = train_test_split(patients, test_size=0.15, random_state=42)

# Split the train set into the real train set and a test set
patients_train, patients_test = train_test_split(patients_train, test_size=0.15, random_state=42)

# Print data distribution
print(f"Train length: {len(patients_train)}")
print(f"Validation length: {len(patients_val)}")
print(f"Test length: {len(patients_test)}")

class DataGenerator(keras.utils.Sequence):
    def __init__(self, list_IDs, data_path, batch_size=1, img_size=IMG_SIZE, n_channels=N_CHANNELS, n_classes=2, shuffle=True):
        self.list_IDs = list_IDs
        self.data_path = data_path
        self.batch_size = batch_size
        self.img_size = img_size
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size: (index + 1) * self.batch_size]
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        X, y = self.__data_generation(list_IDs_temp)
        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        X = np.zeros((self.batch_size * VOLUME_SLICES, self.img_size, self.img_size, self.n_channels))
        y = np.zeros((self.batch_size * VOLUME_SLICES, self.img_size, self.img_size, self.n_classes))

        for c, i in enumerate(list_IDs_temp):
            t1_path = os.path.join(self.data_path, i, 'pre', 'T1.nii.gz')
            flair_path = os.path.join(self.data_path, i, 'pre', 'FLAIR.nii.gz')
            seg_path = os.path.join(self.data_path, i, 'wmh_modified.nii.gz')

            t1 = nib.load(t1_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()

            for j in range(VOLUME_SLICES):
                X[j + VOLUME_SLICES * c, :, :, 0] = cv2.resize(t1[:, :, j + VOLUME_START_AT], (self.img_size, self.img_size))
                X[j + VOLUME_SLICES * c, :, :, 1] = cv2.resize(flair[:, :, j + VOLUME_START_AT], (self.img_size, self.img_size))

                # Resize and create one-hot encoded mask
                mask_resized = cv2.resize(seg[:, :, j + VOLUME_START_AT], (self.img_size, self.img_size), interpolation=cv2.INTER_NEAREST)
                y[j + VOLUME_SLICES * c, :, :, :] = tf.keras.utils.to_categorical(mask_resized, num_classes=self.n_classes)

        return X / np.max(X), y

# Create data generators
train_generator = DataGenerator(patients_train, data_path, n_channels=N_CHANNELS)
val_generator = DataGenerator(patients_val, data_path, n_channels=N_CHANNELS)
test_generator = DataGenerator(patients_test, data_path, n_channels=N_CHANNELS)
# Out:
# Train length: 14
# Validation length: 3
# Test length: 3

# %% [markdown]
# ### U-Net architecture

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, concatenate
from tensorflow.keras.models import Model
def unet_model(inputs, ker_init, dropout):
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)

    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(3, 1, activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, concatenate
from tensorflow.keras.models import Model
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)

    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv4)

    pool5 = MaxPooling2D(pool_size=(2, 2))(conv4)
    conv6 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool5)
    conv6 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv6)
    drop6 = Dropout(dropout)(conv6)

    up8 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop6))
    merge8 = concatenate([conv4,up8], axis = 3)
    conv8 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv3,up9], axis = 3)
    conv9 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up10 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge10 = concatenate([conv2,up10], axis = 3)
    conv10 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge10)
    conv10 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv10)

    up11 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv10))
    merge11 = concatenate([conv,up11], axis = 3)
    conv11 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge11)
    conv11 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv11)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv11))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv12 = Conv2D(2, 1, activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv12)

# %% [markdown]
# ### Metrics for training

# %%
import keras.backend as K
# Compute metric between the predicted segmentation and the ground truth
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 2
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %%
# Define input data shape
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

# Build and compile the model
model = unet_model(input_layer, 'he_normal', 0.5)

model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=3), dice_coef, precision])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-9c36e3b5240f> in <cell line: 5>()
#       3
#       4 # Build and compile the model
# ----> 5 model = unet_model(input_layer, 'he_normal', 0.5)
#       6
#       7 model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#
# <ipython-input-9-61e95ffa6709> in unet_model(inputs, ker_init, dropout)
#      42
#      43     up11 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv10))
# ---> 44     merge11 = concatenate([conv,up11], axis = 3)
#      45     conv11 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge11)
#      46     conv11 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv11)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/merging/concatenate.py in concatenate(inputs, axis, **kwargs)
#     229         A tensor, the concatenation of the inputs alongside axis `axis`.
#     230     """
# --> 231     return Concatenate(axis=axis, **kwargs)(inputs)
#     232
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/merging/concatenate.py in build(self, input_shape)
#     129                 )
#     130                 if len(unique_dims) > 1:
# --> 131                     raise ValueError(err_msg)
#     132
#     133     def _merge_function(self, inputs):
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concatenation axis. Received: input_shape=[(None, 128, 128, 64), (None, 256, 256, 64)]

# %% [markdown]
# ### Training

# %%
from keras.callbacks import CSVLogger
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=10, min_lr=0.000001, verbose=1),

    keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.h5',
                             verbose=1, save_best_only=True, save_weights_only = True),

    CSVLogger('training.log', separator=',', append=False)
]

# %%
model.fit(train_generator,
          epochs=50,
          steps_per_epoch=len(patients_train),
          callbacks=callbacks,
          validation_data=val_generator)
# Out:
# Epoch 1/50
# 14/14 [==============================] - ETA: 0s - loss: 4.1982 - accuracy: 0.9225 - mean_io_u_1: 0.4137 - dice_coef: 0.4536 - precision: 0.9225
# Epoch 1: val_loss improved from inf to 0.22702, saving model to model_.01-0.227021.h5
# 14/14 [==============================] - 96s 3s/step - loss: 4.1982 - accuracy: 0.9225 - mean_io_u_1: 0.4137 - dice_coef: 0.4536 - precision: 0.9225 - val_loss: 0.2270 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.2500 - val_dice_coef: 0.4490 - val_precision: 0.9943 - lr: 0.0010
# Epoch 2/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9948 - mean_io_u_1: 0.5885 - dice_coef: 0.4943 - precision: 0.9948
# Epoch 2: val_loss improved from 0.22702 to 0.03494, saving model to model_.02-0.034941.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.0583 - accuracy: 0.9948 - mean_io_u_1: 0.5885 - dice_coef: 0.4943 - precision: 0.9948 - val_loss: 0.0349 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.5927 - val_dice_coef: 0.5026 - val_precision: 0.9943 - lr: 0.0010
# Epoch 3/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9948 - mean_io_u_1: 0.6524 - dice_coef: 0.5003 - precision: 0.9948
# Epoch 3: val_loss improved from 0.03494 to 0.02984, saving model to model_.03-0.029841.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.0333 - accuracy: 0.9948 - mean_io_u_1: 0.6524 - dice_coef: 0.5003 - precision: 0.9948 - val_loss: 0.0298 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6537 - val_dice_coef: 0.5072 - val_precision: 0.9943 - lr: 0.0010
# Epoch 4/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9948 - mean_io_u_1: 0.6658 - dice_coef: 0.5047 - precision: 0.9948
# Epoch 4: val_loss did not improve from 0.02984
# 14/14 [==============================] - 30s 2s/step - loss: 0.0286 - accuracy: 0.9948 - mean_io_u_1: 0.6658 - dice_coef: 0.5047 - precision: 0.9948 - val_loss: 0.0310 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7029 - val_dice_coef: 0.5073 - val_precision: 0.9943 - lr: 0.0010
# Epoch 5/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9948 - mean_io_u_1: 0.6485 - dice_coef: 0.5035 - precision: 0.9948
# Epoch 5: val_loss improved from 0.02984 to 0.02746, saving model to model_.05-0.027461.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.0314 - accuracy: 0.9948 - mean_io_u_1: 0.6485 - dice_coef: 0.5035 - precision: 0.9948 - val_loss: 0.0275 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6340 - val_dice_coef: 0.5104 - val_precision: 0.9943 - lr: 0.0010
# Epoch 6/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9948 - mean_io_u_1: 0.6722 - dice_coef: 0.5099 - precision: 0.9948
# Epoch 6: val_loss improved from 0.02746 to 0.02434, saving model to model_.06-0.024338.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.0255 - accuracy: 0.9948 - mean_io_u_1: 0.6722 - dice_coef: 0.5099 - precision: 0.9948 - val_loss: 0.0243 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7422 - val_dice_coef: 0.5222 - val_precision: 0.9943 - lr: 0.0010
# Epoch 7/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9948 - mean_io_u_1: 0.6938 - dice_coef: 0.5190 - precision: 0.9948
# Epoch 7: val_loss improved from 0.02434 to 0.02384, saving model to model_.07-0.023838.h5
# 14/14 [==============================] - 30s 2s/step - loss: 0.0222 - accuracy: 0.9948 - mean_io_u_1: 0.6938 - dice_coef: 0.5190 - precision: 0.9948 - val_loss: 0.0238 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6977 - val_dice_coef: 0.5230 - val_precision: 0.9943 - lr: 0.0010
# Epoch 8/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9948 - mean_io_u_1: 0.7292 - dice_coef: 0.5256 - precision: 0.9948
# Epoch 8: val_loss improved from 0.02384 to 0.02079, saving model to model_.08-0.020791.h5
# 14/14 [==============================] - 30s 2s/step - loss: 0.0220 - accuracy: 0.9948 - mean_io_u_1: 0.7292 - dice_coef: 0.5256 - precision: 0.9948 - val_loss: 0.0208 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7111 - val_dice_coef: 0.5408 - val_precision: 0.9943 - lr: 0.0010
# Epoch 9/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9948 - mean_io_u_1: 0.7459 - dice_coef: 0.5255 - precision: 0.9948
# Epoch 9: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0245 - accuracy: 0.9948 - mean_io_u_1: 0.7459 - dice_coef: 0.5255 - precision: 0.9948 - val_loss: 0.0229 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6490 - val_dice_coef: 0.5349 - val_precision: 0.9943 - lr: 0.0010
# Epoch 10/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9948 - mean_io_u_1: 0.6833 - dice_coef: 0.5289 - precision: 0.9948
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 10: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0216 - accuracy: 0.9948 - mean_io_u_1: 0.6833 - dice_coef: 0.5289 - precision: 0.9948 - val_loss: 0.0219 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6707 - val_dice_coef: 0.5384 - val_precision: 0.9943 - lr: 0.0010
# Epoch 11/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9948 - mean_io_u_1: 0.6895 - dice_coef: 0.5427 - precision: 0.9948
# Epoch 11: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0178 - accuracy: 0.9948 - mean_io_u_1: 0.6895 - dice_coef: 0.5427 - precision: 0.9948 - val_loss: 0.0215 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6912 - val_dice_coef: 0.5390 - val_precision: 0.9943 - lr: 2.0000e-04
# Epoch 12/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9948 - mean_io_u_1: 0.7270 - dice_coef: 0.5436 - precision: 0.9948
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 12: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0174 - accuracy: 0.9948 - mean_io_u_1: 0.7270 - dice_coef: 0.5436 - precision: 0.9948 - val_loss: 0.0213 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7035 - val_dice_coef: 0.5418 - val_precision: 0.9943 - lr: 2.0000e-04
# Epoch 13/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9948 - mean_io_u_1: 0.7165 - dice_coef: 0.5502 - precision: 0.9948
# Epoch 13: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0166 - accuracy: 0.9948 - mean_io_u_1: 0.7165 - dice_coef: 0.5502 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.6989 - val_dice_coef: 0.5436 - val_precision: 0.9943 - lr: 4.0000e-05
# Epoch 14/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9948 - mean_io_u_1: 0.7191 - dice_coef: 0.5512 - precision: 0.9948
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 14: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0164 - accuracy: 0.9948 - mean_io_u_1: 0.7191 - dice_coef: 0.5512 - precision: 0.9948 - val_loss: 0.0212 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7039 - val_dice_coef: 0.5424 - val_precision: 0.9943 - lr: 4.0000e-05
# Epoch 15/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9948 - mean_io_u_1: 0.7200 - dice_coef: 0.5516 - precision: 0.9948
# Epoch 15: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0162 - accuracy: 0.9948 - mean_io_u_1: 0.7200 - dice_coef: 0.5516 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7035 - val_dice_coef: 0.5427 - val_precision: 0.9943 - lr: 8.0000e-06
# Epoch 16/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7207 - dice_coef: 0.5521 - precision: 0.9948
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 16: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7207 - dice_coef: 0.5521 - precision: 0.9948 - val_loss: 0.0212 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5427 - val_precision: 0.9943 - lr: 8.0000e-06
# Epoch 17/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5521 - precision: 0.9948
# Epoch 17: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5521 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5427 - val_precision: 0.9943 - lr: 1.6000e-06
# Epoch 18/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5522 - precision: 0.9948
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 18: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5522 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5428 - val_precision: 0.9943 - lr: 1.6000e-06
# Epoch 19/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5521 - precision: 0.9948
# Epoch 19: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5521 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5428 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 20/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5522 - precision: 0.9948
# Epoch 20: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5522 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7044 - val_dice_coef: 0.5428 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 21/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5523 - precision: 0.9948
# Epoch 21: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5523 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5429 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 22/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5523 - precision: 0.9948
# Epoch 22: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5523 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5429 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 23/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5523 - precision: 0.9948
# Epoch 23: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5523 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5430 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 24/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5524 - precision: 0.9948
# Epoch 24: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5524 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5430 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 25/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5524 - precision: 0.9948
# Epoch 25: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5524 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5430 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 26/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5524 - precision: 0.9948
# Epoch 26: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5524 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5431 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 27/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5525 - precision: 0.9948
# Epoch 27: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5525 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5431 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 28/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5527 - precision: 0.9948
# Epoch 28: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5527 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5432 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 29/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5527 - precision: 0.9948
# Epoch 29: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5527 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5432 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 30/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5526 - precision: 0.9948
# Epoch 30: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5526 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5432 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 31/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5528 - precision: 0.9948
# Epoch 31: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0161 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5528 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5432 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 32/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5528 - precision: 0.9948
# Epoch 32: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5528 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5433 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 33/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5529 - precision: 0.9948
# Epoch 33: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5529 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5433 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 34/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5529 - precision: 0.9948
# Epoch 34: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5529 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5434 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 35/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5530 - precision: 0.9948
# Epoch 35: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5530 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7041 - val_dice_coef: 0.5435 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 36/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5529 - precision: 0.9948
# Epoch 36: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5529 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5435 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 37/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5531 - precision: 0.9948
# Epoch 37: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5531 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5435 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 38/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5531 - precision: 0.9948
# Epoch 38: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5531 - precision: 0.9948 - val_loss: 0.0211 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5435 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 39/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5533 - precision: 0.9948
# Epoch 39: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5533 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5436 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 40/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5532 - precision: 0.9948
# Epoch 40: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5532 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7041 - val_dice_coef: 0.5437 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 41/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5532 - precision: 0.9948
# Epoch 41: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5532 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7043 - val_dice_coef: 0.5436 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 42/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5533 - precision: 0.9948
# Epoch 42: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5533 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5437 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 43/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5534 - precision: 0.9948
# Epoch 43: val_loss did not improve from 0.02079
# 14/14 [==============================] - 31s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5534 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5438 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 44/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5535 - precision: 0.9948
# Epoch 44: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5535 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7041 - val_dice_coef: 0.5439 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 45/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5535 - precision: 0.9948
# Epoch 45: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5535 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7044 - val_dice_coef: 0.5438 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 46/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5536 - precision: 0.9948
# Epoch 46: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7209 - dice_coef: 0.5536 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5439 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 47/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5537 - precision: 0.9948
# Epoch 47: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7208 - dice_coef: 0.5537 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7042 - val_dice_coef: 0.5439 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 48/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7210 - dice_coef: 0.5536 - precision: 0.9948
# Epoch 48: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0160 - accuracy: 0.9948 - mean_io_u_1: 0.7210 - dice_coef: 0.5536 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7044 - val_dice_coef: 0.5439 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 49/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9948 - mean_io_u_1: 0.7211 - dice_coef: 0.5537 - precision: 0.9948
# Epoch 49: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0159 - accuracy: 0.9948 - mean_io_u_1: 0.7211 - dice_coef: 0.5537 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7045 - val_dice_coef: 0.5440 - val_precision: 0.9943 - lr: 1.0000e-06
# Epoch 50/50
# 14/14 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9948 - mean_io_u_1: 0.7211 - dice_coef: 0.5537 - precision: 0.9948
# Epoch 50: val_loss did not improve from 0.02079
# 14/14 [==============================] - 30s 2s/step - loss: 0.0159 - accuracy: 0.9948 - mean_io_u_1: 0.7211 - dice_coef: 0.5537 - precision: 0.9948 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_mean_io_u_1: 0.7045 - val_dice_coef: 0.5440 - val_precision: 0.9943 - lr: 1.0000e-06

# %%
import pandas as pd
# Read the CSVlogger file that contains all our metrics (accuracy, loss, dice_coef, ...) of our training
history = pd.read_csv('training.log', sep=',', engine='python')

# Plot training and validation metrics
fig, axs = plt.subplots(1, 4, figsize=(16, 8))

axs[0].plot(history['epoch'], history['accuracy'], 'b', label='Training Accuracy')
axs[0].plot(history['epoch'], history['val_accuracy'], 'r', label='Validation Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

axs[1].plot(history['epoch'], history['loss'], 'b', label='Training Loss')
axs[1].plot(history['epoch'], history['val_loss'], 'r', label='Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(history['epoch'], history['dice_coef'], 'b', label='Training dice coef')
axs[2].plot(history['epoch'], history['val_dice_coef'], 'r', label='Validation dice coef')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Dice Coefficient')
axs[2].legend()

axs[3].plot(history['epoch'], history['mean_io_u_1'], 'b', label='Training mean IOU')
axs[3].plot(history['epoch'], history['val_mean_io_u_1'], 'r', label='Validation mean IOU')
axs[3].set_xlabel('Epoch')
axs[3].set_ylabel('Mean IOU')
axs[3].legend()

# Add space between subplots
plt.subplots_adjust(wspace=0.4)

plt.show()

# %%
# Compile a model and load our saved weights
IMG_SIZE = 256
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

best_saved_model = unet_model(input_layer, 'he_normal', 0.5)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                         metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=3), dice_coef, precision] )

best_saved_model.load_weights('/content/model_.08-0.020791.h5')

# %% [markdown]
# ### Prediction

# %%
#model_path = ('/content/model_.15-0.034663.h5')
#loaded_model = tf.keras.models.load_model(model_path)

def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 2
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

#loaded_model = tf.keras.models.load_model(model_path, custom_objects= {'dice_coef': dice_coef, 'precision': precision})

def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1_path = os.path.join(sample_path, 'pre', 'T1.nii.gz')
    flair_path = os.path.join(sample_path, 'pre', 'FLAIR.nii.gz')

    # Extract the data from these paths
    t1 = nib.load(t1_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j, :, :, 0] = cv2.resize(t1[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 1] = cv2.resize(flair[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X / np.max(X), verbose=1)

# %%
import random
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm, model):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(data_path, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = os.path.join(random_sample_path, 'wmh_modified.nii.gz')
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions.
    seg = cv2.resize(seg[:, :, slice_to_plot + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)

    # Ensure slice_to_plot is within the valid range
    num_slices_predicted = predicted_seg.shape[0]
    slice_to_plot = min(slice_to_plot, num_slices_predicted - 1)

    # Differentiate segmentations by their labels
    #all = predicted_seg[slice_to_plot, :, :, 1:3]  # Keep only classes 1 and 2
    zero = predicted_seg[slice_to_plot, :, :, 0]    # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot, :, :, 1]    # Isolation of class 1, White Matter Hyperintensity
    #second = predicted_seg[slice_to_plot, :, :, 2]   # Isolation of class 2, Other Pathology

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 3, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    #axstest[1].imshow(all[:, :, 0], cmap, norm)  # Display the first channel
    #axstest[1].set_title('Predicted Segmentation - all layers')

    # Layer 0
    axstest[1].imshow(zero, cmap, norm)
    axstest[1].set_title('Predicted Segmentation - layer 0')

    # Layer 1
    axstest[2].imshow(first, cmap, norm)
    axstest[2].set_title('Predicted Segmentation - layer 1')

    # Layer 2
    #axstest[4].imshow(second, cmap, norm)
    #axstest[4].set_title('Predicted Segmentation - layer 2')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.4)

    plt.show()

# Example usage
show_predicted_segmentations(patients_test, slice_to_plot=22, cmap='gray', norm=None, model=model)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Patient number:  25
